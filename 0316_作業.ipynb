# %% [markdown]
# <a href="https://colab.research.google.com/github/s10955028/bigdata/blob/main/0316_%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 列出檔案
system("ls", TRUE)
library(readr)
dataset <- read.csv("A53000000A-110025-003 (1).csv")
dataset
# Out:
# [1] "A53000000A-110025-003 (1).csv" "sample_data"
#    Seq DateListed 年度 場館                                               一月
# 1   1  2021/03/03 109  基隆市原住民文化會館                                3574
# 2   2  2021/03/03 109  臺北市政府原委員會凱達格蘭文化館                   20222
# 3   3  2021/03/03 109  新北市烏來泰雅民族博物館                           27021
# 4   4  2021/03/03 109  桃園市原住民文化會館                                8250
# 5   5  2021/03/03 109  新竹縣五峰鄉賽夏族矮人祭場文物館                     615
# 6   6  2021/03/03 109  新竹縣尖石鄉原住民文化館                            6230
# 7   7  2021/03/03 109  苗栗縣賽夏族民俗文物館                              1651
# 8   8  2021/03/03 109  苗栗縣泰雅文物館                                    3244
# 9   9  2021/03/03 109  臺中市原住民綜合服務中心                            2567
# 10 10  2021/03/03 109  彰化縣原住民生活館                                  1022
# 11 11  2021/03/03 109  嘉義縣阿里山鄒族自然與文化中心                      1286
# 12 12  2021/03/03 109  臺南市原住民會館(札哈木）                           1315
# ...

# %%
head(dataset$場館, n=15)
# Out:
#  [1] "基隆市原住民文化會館"
#  [2] "臺北市政府原委員會凱達格蘭文化館"
#  [3] "新北市烏來泰雅民族博物館"
#  [4] "桃園市原住民文化會館"
#  [5] "新竹縣五峰鄉賽夏族矮人祭場文物館"
#  [6] "新竹縣尖石鄉原住民文化館"
#  [7] "苗栗縣賽夏族民俗文物館"
#  [8] "苗栗縣泰雅文物館"
#  [9] "臺中市原住民綜合服務中心"
# [10] "彰化縣原住民生活館"
# [11] "嘉義縣阿里山鄒族自然與文化中心"
# [12] "臺南市原住民會館(札哈木）"
# [13] "臺南市原住民文物館（Palihanbasan巴里和巴桑故事館）"
# [14] "高雄市那瑪夏區原住民文物館"
# [15] "高雄市桃源區原住民文物館"

# %%
tail(dataset$場館, n=20)
# Out:
#  [1] "彰化縣原住民生活館"
#  [2] "嘉義縣阿里山鄒族自然與文化中心"
#  [3] "臺南市原住民會館(札哈木）"
#  [4] "臺南市原住民文物館（Palihanbasan巴里和巴桑故事館）"
#  [5] "高雄市那瑪夏區原住民文物館"
#  [6] "高雄市桃源區原住民文物館"
#  [7] "屏東縣原住民文化會館"
#  [8] "屏東縣三地門鄉原住民文化館"
#  [9] "屏東縣霧台鄉魯凱族文物館"
# [10] "屏東縣來義鄉原住民文物館"
# [11] "屏東縣獅子鄉文物陳列館"
# [12] "臺東縣海端鄉布農族文化館"
# [13] "臺東縣成功鎮原住民文物館 "
# [14] "花蓮縣瑞穗鄉奇美原住民文物館"
# [15] "花蓮縣萬榮鄉原住民文物館 "
# [16] "花蓮縣壽豐鄉原住民文物館"
# [17] "花蓮縣吉安鄉阿美族文物館"
# [18] "台灣原住民族文化館（花蓮縣）"
# [19] "宜蘭縣大同鄉泰雅生活館"
# [20] "宜蘭縣南澳鄉泰雅文化館"

# %%
head(dataset$一月, n=10)
# Out:
#  [1]  3574 20222 27021  8250   615  6230  1651  3244  2567  1022

# %%
head(dataset$三月, n=10)
# Out:
#  [1]  3570 13039  5107  6408   284  2970   915  1956  2969   767

# %%
dataset[grepl("高雄",dataset$場館),]
# Out:
#    Seq DateListed 年度 場館                       一月 二月 三月 四月    五月
# 14 14  2021/03/03 109  高雄市那瑪夏區原住民文物館  706 848  1663 1,767   1866
# 15 15  2021/03/03 109  高雄市桃源區原住民文物館   1047 432   328 652      982
# 43 43  2021/03/03 108  高雄市那瑪夏區原住民文物館  529 234   430 785      535
# 44 44  2021/03/03 108  高雄市桃源區原住民文物館    577 522  1477 395      444
# 72 72  2021/03/03 107  高雄市那瑪夏區原住民文物館  327 619   426  2,065  1054
# 73 73  2021/03/03 107  高雄市桃源區原住民文物館    515 580   612  955     675
#    六月 七月 八月 九月 十月 十一月 十二月
# 14 1454 1409 1445 809    NA   NA     NA
# 15  972  709 1825 684    NA   NA     NA
# 43  261  529  798 602  1439 1010    930
# 44  571 1403 1401 570   811  895    978
# 72  428  285  211 275   678  291    479
# 73  431  526  504 809  1189 1128   2000

# %%
dataset[grepl("桃園",dataset$場館),]
# Out:
#    Seq DateListed 年度 場館                 一月 二月 三月 四月    五月  六月
# 4   4  2021/03/03 109  桃園市原住民文化會館 8250 4709 6408 3,690    4181 4827
# 33 33  2021/03/03 108  桃園市原住民文化會館 4802 4354 9350 12,019  11633 9238
# 62 62  2021/03/03 107  桃園市原住民文化會館 1775  650 4293  7,343   7213 7665
#    七月  八月  九月  十月  十一月 十二月
# 4   7924  8596 11730    NA    NA     NA
# 33 11186 16048 14788 10062 18648  13229
# 62 10610  7571  8660 12183 12833  12852

# %%
dataset[grepl("臺南",dataset$場館),]
# Out:
#    Seq DateListed 年度 場館                                               一月
# 12 12  2021/03/03 109  臺南市原住民會館(札哈木）                          1315
# 13 13  2021/03/03 109  臺南市原住民文物館（Palihanbasan巴里和巴桑故事館）  528
# 41 41  2021/03/03 108  臺南市原住民會館(札哈木）                          2912
# 42 42  2021/03/03 108  臺南市原住民文物館（Palihanbasan巴里和巴桑故事館）  914
# 70 70  2021/03/03 107  臺南市原住民會館(札哈木）                           592
# 71 71  2021/03/03 107  臺南市原住民文物館（Palihanbasan巴里和巴桑故事館） 1138
#    二月 三月 四月    五月 六月 七月 八月 九月 十月 十一月 十二月
# 12 899   906 428     1636 3602 3036 6281 5120   NA   NA     NA
# 13 263   100 160      200  660  750  811  600   NA   NA     NA
# 41 890  2591 2,455   3229 3703 2767 2311 4168 6596 8055   5266
# 42 629   870 828     1013 1031  331 1175 1092  622  657    595
# 70 581  2565  1,920  2037 2909 7307 1721 1272 5722 7376   5903
# 71 811  1222  1,127  1669 1743 1747 1278 1228 1382 1211    976
